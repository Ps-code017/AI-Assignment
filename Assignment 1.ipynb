# %%
#Q1
students_marks = []
for i in range(10):
    marks = list(map(int, input(f"Enter marks for student {i+1} (Maths, Science, English, IT): ").split()))
    students_marks.append(marks)

# Calculate highest, lowest, and average for each subject
subjects = ['Maths', 'Science', 'English', 'IT']
for i in range(4):
    subject_marks = [marks[i] for marks in students_marks]
    print(f"{subjects[i]} - Highest: {max(subject_marks)}, Lowest: {min(subject_marks)}, Average: {sum(subject_marks)/len(subject_marks)}")

# Calculate highest, lowest, and average overall
overall_marks = [sum(marks) for marks in students_marks]
print(f"Overall - Highest: {max(overall_marks)}, Lowest: {min(overall_marks)}, Average: {sum(overall_marks)/len(overall_marks)}")



#Q2
basic_salary = float(input("Enter basic salary: "))

# Calculate HRA and DA based on salary ranges
if basic_salary <= 10000:
    hra = basic_salary * 0.20
    da = basic_salary * 0.80
elif basic_salary <= 20000:
    hra = basic_salary * 0.25
    da = basic_salary * 0.90
else:
    hra = basic_salary * 0.30
    da = basic_salary * 0.95

# Calculate Gross Salary
gross_salary = basic_salary + hra + da
print(f"Gross Salary: {gross_salary}")

#Q3
import re

def validate_password(password):
    if (len(password) >= 6 and len(password) <= 16 and
        re.search("[a-z]", password) and
        re.search("[A-Z]", password) and
        re.search("[0-9]", password) and
        re.search("[$#@]", password)):
        return True
    else:
        return False

# Input password
password = input("Enter password: ")

if validate_password(password):
    print("Password is valid.")
else:
    print("Password is invalid.")


#Q4
L = [10, 20, 30, 40, 50, 60, 70, 80]

# (i) Add 200 and 300
L.append(200)
L.append(300)

# (ii) Remove 10 and 30
L.remove(10)
L.remove(30)

# (iii) Sort L in ascending order
L.sort()
print(f"List sorted in ascending order: {L}")

# (iv) Sort L in descending order
L.sort(reverse=True)
print(f"List sorted in descending order: {L}")


#Q5
D = {1: "One", 2: "Two", 3: "Three", 4: "Four", 5: "Five"}

# (i) Add new entry with key 6 and value "Six"
D[6] = "Six"

# (ii) Remove key 2
del D[2]

# (iii) Check if key 6 is present
if 6 in D:
    print("Key 6 is present in the dictionary.")

# (iv) Count the number of elements in D
print(f"Number of elements in D: {len(D)}")

# (v) Add all the values in D
total = sum([len(value) for value in D.values()])
print(f"Total length of all values: {total}")


#Q6
import random

# Create list of 100 random numbers between 100 and 900
random_numbers = [random.randint(100, 900) for _ in range(100)]

# Count odd, even, and prime numbers
odd_count = sum(1 for num in random_numbers if num % 2 != 0)
even_count = sum(1 for num in random_numbers if num % 2 == 0)

def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

prime_count = sum(1 for num in random_numbers if is_prime(num))

print(f"Odd numbers count: {odd_count}")
print(f"Even numbers count: {even_count}")
print(f"Prime numbers count: {prime_count}")


#Q7
# (i) Function to calculate compound interest
def compound_interest(principal, rate, time):
    return principal * (1 + rate/100)**time - principal

# Call the function
p = float(input("Enter principal amount: "))
r = float(input("Enter interest rate: "))
t = float(input("Enter time period in years: "))

interest = compound_interest(p, r, t)
print(f"Compound Interest: {interest}")

# (ii) Save this function as compound_interest.py and import it in another file
# In the file Compound_Interest.py
def compound_interest(principal, rate, time):
    return principal * (1 + rate/100)**time - principal
#Import it to some other file
from compound_interest import compound_interest

# Call the function
p = float(input("Enter principal amount: "))
r = float(input("Enter interest rate: "))
t = float(input("Enter time period in years: "))

interest = compound_interest(p, r, t)
print(f"Compound Interest: {interest}")

#Q8
# A) Restaurant Class
class Restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type

    def describe_restaurant(self):
        print(f"Restaurant: {self.restaurant_name}, Cuisine: {self.cuisine_type}")

    def open_restaurant(self):
        print(f"{self.restaurant_name} is now open!")

# Create an instance and call the methods
restaurant = Restaurant("The Taste", "Italian")
restaurant.describe_restaurant()
restaurant.open_restaurant()

# B) User Class
class User:
    def __init__(self, first_name, last_name, age, location):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.location = location

    def describe_user(self):
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}, Location: {self.location}")

    def greet_user(self):
        print(f"Hello {self.first_name} {self.last_name}, welcome!")

# Create several user instances and call the methods
user1 = User("John", "Doe", 28, "New York")
user2 = User("Jane", "Smith", 34, "California")

user1.describe_user()
user1.greet_user()

user2.describe_user()
user2.greet_user()
